# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/sibikarthik/*Civilytix'

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("/Users/sibikarthik/*Civilytix/tenders_data_1.csv")

# %%
data.head()
# Out:
#                                             Category  \
# 0                             Services: Professional
# 1  Manufacture of computer, electronic and optica...
# 2                Specialised construction activities
# 3                Specialised construction activities
# 4                Specialised construction activities
#
#                                   Tender Description  eSubmission  \
# 0  REQUEST FOR PRICE QUOTATIONS FOR THE APPOINTME...  Not Allowed
# 1                     Tembisa Mag - Toners and Drums  Not Allowed
# 2              Sebokeng Mag - Day to day maintenance  Not Allowed
# 3                Protea Mag - Day to day maintenance  Not Allowed
# 4              Cullinan Mag - Day to day maintenance  Not Allowed
#
#   Advertised Date Awarded Date    Tender Number  \
# 0      18/02/2025   27/02/2025  RFQ2025-002-006
# 1      14/02/2025   21/02/2025       POS0000C5X
# 2      14/02/2025   25/02/2025       POS0000C7J
# ...

# %%
data.describe()
# Out:
#                       Category  \
# count                    20549
# unique                      89
# top     Services: Professional
# freq                      2842
#
#                                        Tender Description  eSubmission  \
# count                                               20549        20549
# unique                                              20039            2
# top     CONSTRUCTION OF SANITATION FACILITIES AT SCHOO...  Not Allowed
# freq                                                   40        20343
#
#        Advertised Date Awarded Date      Tender Number  \
# count            20549        13957              20541
# unique            1190          835              20373
# top         15/12/2022   28/02/2024  It is a deviation
# freq               115           96                 13
#
#                                   Department                   Tender Type  \
# count                                  20549                         20468
# ...

# %%
data.columns
# Out:
# Index(['Category', 'Tender Description', 'eSubmission', 'Advertised Date',
#        'Awarded Date', 'Tender Number', 'Department', 'Tender Type',
#        'Province', 'Date Published', 'Closing Date', 'Location',
#        'Special Conditions', 'Contact Person', 'Email', 'Telephone Number',
#        'FAX Number', 'Briefing Session', 'Is Compulsory',
#        'Briefing Date & Time', 'Briefing Venue', 'Successful Bidder(s)',
#        'Winning Bid Amount', 'Bidders List PDF'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20549 entries, 0 to 20548
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Category              20549 non-null  object
#  1   Tender Description    20549 non-null  object
#  2   eSubmission           20549 non-null  object
#  3   Advertised Date       20549 non-null  object
#  4   Awarded Date          13957 non-null  object
#  5   Tender Number         20541 non-null  object
#  6   Department            20549 non-null  object
#  7   Tender Type           20468 non-null  object
#  8   Province              20549 non-null  object
#  9   Date Published        20549 non-null  object
#  10  Closing Date          20546 non-null  object
#  11  Location              20549 non-null  object
#  12  Special Conditions    8968 non-null   object
#  13  Contact Person        20517 non-null  object
#  14  Email                 20544 non-null  object
# ...

# %%
data.shape
# Out:
# (20549, 24)
